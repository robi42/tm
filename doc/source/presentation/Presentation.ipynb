# %% [markdown]
# # TempMunger
#
# ## A Visual Analytics Approach Supporting <br>Transformations of Time-Oriented Data
#
# Robert Thurnher

# %%
from datetime import date

print(date.today())
# Out:
# 2017-05-29

# %% [markdown]
# # Outline
#
#  * Motivation
#  * Research Questions
#  * State of the Art
#  * Requirements
#  * Methodological Approach
#  * Prototype Design
#  * Demo
#  * Evaluation
#  * Results
#  * Discussion
#  * Future Work
#  * Conclusion

# %% [markdown]
# # Motivation

# %% [markdown]
# **Visual Analytics** (VA), *"the
# science of analytical reasoning facilitated by interactive visual interfaces"* [Thomas and Cook, 2005], [Loukides, 2010]:

# %% [markdown]
#  1. **Data wrangling** a.k.a. **munging**
#  1. Statistics & machine learning
#  1. Visualization & analysis itself

# %% [markdown]
# ## Data Wrangling
#
# ... generally denotes the cumbersome task of making data useful for analysis.

# %% [markdown]
#  * **Tedious** task
#  * **High-level** support
#  * **Time-oriented** data

# %% [markdown]
# $$\rightarrow \textbf{TempMunger}$$

# %% [markdown]
# # Research Questions
#
# ***How can we support data wrangling with VA techniques?***

# %% [markdown]
# ## Subquestions
#
#  * *Which data transformations are best supported by analytical
# methods and for which transformations is visual support
# beneficial?*

# %% [markdown]
#  * *How do concrete data wrangling workflow processes look like
# and how can these processes be supported by VA methods?*

# %% [markdown]
#  * *What data wrangling tasks need to be tackled in particular
# when dealing with time-oriented data and how can we support
# them with VA methods?*

# %% [markdown]
# # State of the Art

# %% [markdown]
# ## DataWrangler
#
# [Kandel et al., 2011]

# %%
from IPython.core.display import Image, display

display(Image('../thesis/figures/state-of-the-art/data-wrangler.png', width=600))

# %% [markdown]
# ## OpenRefine
#
# [openrefine.org](http://openrefine.org/)

# %%
from IPython.core.display import Image, display

display(Image('../thesis/figures/state-of-the-art/google-refine.png', width=600))

# %% [markdown]
# ## Kibana Timelion
#
# [Khan, 2015]

# %%
from IPython.core.display import Image, display

display(Image('../thesis/figures/state-of-the-art/kibana-timelion.png', width=600))

# %% [markdown]
# ## Jupyter Notebooks
#
# [jupyter.org](https://jupyter.org/)

# %%
from IPython.core.display import Image, display

display(Image('../thesis/figures/state-of-the-art/jupyter-notebooks.png', width=500))

# %% [markdown]
# |               | *DataWrangler* |  *OpenRefine* |  *Timelion* |   *Jupyter*  |
# |---------------|:--------------:|:-----------  :|:-----------:|:------------:|
# | Time-Oriented |       No       |      Yes      |    Focus    |   Supported  |
# | Charting      |     Little     |      Some     |  Extensive  |   Extensive  |
# | Approach      |   Spreadsheet  |  Spreadsheet  |  CLI + DSL  |  CLI + REPL  |

# %% [markdown]
# |               | *DataWrangler* |  *OpenRefine* |  *Timelion* |   *Jupyter*  |   *TempMunger*   |
# |---------------|:--------------:|:-----------  :|:-----------:|:------------:|:----------------:|
# | Time-Oriented |       No       |      Yes      |    Focus    |   Supported  |     **Focus**    |
# | Charting      |     Little     |      Some     |  Extensive  |   Extensive  |     **Focus**    |
# | Approach      |   Spreadsheet  |  Spreadsheet  |  CLI + DSL  |  CLI + REPL  |   **Dashboard**  |

# %% [markdown]
# # Requirements
#
# Derived from:
#  * State of the art review
#  * Requirements analysis

# %% [markdown]
#  * **R1:** The prototype must be capable of loading and working with diverse datasets

# %% [markdown]
#  * **R2:** Moreover, it must be intuitive for casual users (i.e., less technically expertized)

# %% [markdown]
#  * **R3:** Yet, some shortcuts for rather power users should be supported as well

# %% [markdown]
#  * **R4:** Focus of our approach has to be on visual-interactive charting aid

# %% [markdown]
#  * **R5:** These charts must be centered on applying time-oriented data transformations

# %% [markdown]
#  * **R6:** Plus, they should provide extraordinary visual overview of the dataset at hand

# %% [markdown]
#  * **R7:** Thus, focus has to be put on choosing most effective and efficient visualizations

# %% [markdown]
#  * **R8:** Furthermore, interactively exploring data must be conveniently possible

# %% [markdown]
#  * **R9:** A more traditional tabular editor should be available with direct manipulation

# %% [markdown]
#  * **R10:** Editing time-oriented data should be supported by specific UI controls

# %% [markdown]
#  * **R11:** Data quality issues need to be easily identifiable and effectually addressable

# %% [markdown]
#  * **R12:** Conveniently spotting data anomalies respectively outliers should be possible

# %% [markdown]
#  * **R13:** Concrete time-oriented data transformation operations to be supported:
#   * Data cleaning regarding missing and erroneous values
#   * Normalization concerning points in time and intervals
#   * Merging columns in an intuitive visual-interactive way
#   * Formatting cleanup, e.g., inconsistencies or conversion

# %% [markdown]
# # Methodological Approach

# %% [markdown]
# Iterative **design**, **implementation**, and
# **evaluation** of a software **prototype**

# %% [markdown]
# Nested model by [Munzner, 2009], including following steps:
#
#  * State of the art review
#  * Requirements analysis
#  * Design of interactive visualizations and UI
#  * Iterative prototypical implementation
#  * Qualitative evaluation of results

# %% [markdown]
# ## Data–Users–Tasks Triangle
#
# [Miksch and Aigner, 2014]

# %%
from IPython.core.display import Image, display

display(Image('../thesis/figures/introduction/cvast-triangle.png', width=400))

# %% [markdown]
# $$\rightarrow \textbf{UX Personas } \text{[Cooper, 2004]}$$

# %% [markdown]
# # Prototype Design

# %% [markdown]
# ## Wireframing with UI Mockups

# %%
from IPython.core.display import Image, display

display(Image('../thesis/figures/design/mockup-6.png', width=800))

# %% [markdown]
# ## Prototyping with Agile Development

# %%
from IPython.core.display import Image, display

display(Image('../thesis/figures/implementation/screenshot-charts-page.png', width=550))

# %% [markdown]
# ## Developed Features

# %% [markdown]
#  * **Transformations**
#   * **Direct manipulation** via UI controls
#   * **Cleaning** of missing and erroneous values
#   * **Normalization** concerning: points in time & intervals
#   * **Deletion** of rows
#   * **Merging** of columns
#   * **Formatting** cleanup

# %% [markdown]
#  * **Outlier detection**
#  * **Visual overview**

# %% [markdown]
# ## Software Architecture

# %%
from IPython.core.display import Image, display

display(Image('../thesis/figures/architecture/system-overview.png', width=350))

# %%
from IPython.core.display import Image, display

display(Image('../thesis/figures/architecture/backend-components.png', width=400))

# %%
from IPython.core.display import Image, display

display(Image('../thesis/figures/architecture/backend-components.png', width=400))

# %% [markdown]
# # [Demo](https://temp-munger.robi42.net/)

# %% [markdown]
# # Evaluation

# %% [markdown]
#  * **Heuristic** evaluation
#  * User/usability **tests**

# %% [markdown]
# ## Evaluation Study Design

# %% [markdown]
# ### Common Setup
#
# That is, shared by both parts of the study:
#
#  * One participant at a time
#  * Introductory explaining session
#  * 10 tasks with goals to perform
#  * Observal and on-demand support
#  * 5 interview questions at the end

# %% [markdown]
# #### Tasks & Goals
#
#  1. Upload a dataset using a given CSV file
#  2. Edit time-oriented data via table editor
#  3. Find potential outliers in the given dataset
#  4. Identify missing respectively erroneous values
#  5. Fill these with actual temporal values and/or delete their entries
#  6. Normalize all entries in a certain month, moving them to another one
#  7. Move all entries on a specific day to another point in time
#  8. Delete all entries within a certain timespan or on a certain date
#  9. Merge time-oriented data columns on the table editor view page
#  10. Export data as CSV, choosing a format for time-oriented values

# %% [markdown]
# #### Interview Questions
#
#  1. What is your overall impression?
#  2. What are the strengths of TempMunger?
#  3. What are the shortcomings of TempMunger?
#  4. Do you believe TempMunger can be useful for you?
#  5. If not, what do you think is needed to make it so?

# %% [markdown]
# ### Heuristic Evaluation
#
#  * 3 usability/InfoVis **experts** [Holzinger, 2005]
#  * 10 classic **heuristics** according to [Nielsen, 1993]
#  * 3 InfoVis-specific heuristics according to [Forsell and Johansson, 2010]

# %% [markdown]
# #### Classic Heuristics
#
#  * Visibility of system status
#  * Match between system and the real world
#  * User control and freedom
#  * Consistency and standards
#  * Error prevention
#  * Recognition rather than recall
#  * Flexibility and efficiency of use
#  * Aesthetic and minimalist design
#  * Help users recognize, diagnose, and recover from errors
#  * Help and documentation

# %% [markdown]
# #### InfoVis Heuristics
#
#  * Information coding
#  * Spatial organization
#  * Remove the extraneous

# %% [markdown]
# ### User Tests
#
#  * 2 **potential users**
#  * Same 10 tasks
#  * Same interview
#  * Focus on:
#   * Impression
#   * Feedback

# %% [markdown]
# $$\rightarrow \text{Potentially revealing other aspects due to different perspective}$$

# %% [markdown]
# # Results

# %% [markdown]
# Our approach and prototype proved to be generally **useful** and **viable**.

# %% [markdown]
#  * *"Good overview"*
#  * *"Can be easily done"*
#  * *"It does what it’s supposed to do"*

# %% [markdown]
# ## Strengths

# %% [markdown]
#  * **Good** visually
# interactive overview offered with charting aid
#  * **Smoothness** regarding UX
#  * **Pleasentness** of general design
#  * **Quality** of present visualizations

# %% [markdown]
# ## Weaknesses

# %% [markdown]
# ... mainly relating to **incompleteness** of supported transformation operations and visualizations.

# %% [markdown]
# ### Heuristic Categories
#
# ordered by frequency descending:
#
#  1. *Information coding*
#  2. *User control and freedom*
#  3. *Spatial organization* + *flexibility and efficiency of use*

# %% [markdown]
# ### Exemplary Found Issues
#
# again, ordered by frequency descending:
#
#  1. Insufficient immediate and intuitive **visual feedback** regarding performed actions, e.g., on missing values cleanup (→ *visibility of system status*)
#  2. **Findability** of modal dialogs for missing values cleanup and interval-based normalization is suboptimal (→ *spatial organization*)
#  3. **Separation** of the two normalization dialogs as well as connected semantics are not intuitive and could be refined (→ *consistency and standards*)

# %% [markdown]
# # Discussion

# %% [markdown]
# ## Open Issues

# %% [markdown]
#  * The usage and behavior of the software is not always intuitive

# %% [markdown]
#  * Immediate visual feedback of system state is partially lacking

# %% [markdown]
#  * Sometimes possible actions are not completely clear to the user

# %% [markdown]
#  * Generally, usability can be improved in some parts of the prototype

# %% [markdown]
#  * Moreover, interactive chart visualizations can be further augmented

# %% [markdown]
#  * Scalability of visualizations should be addressed more

# %% [markdown]
#  * The supported transformation operations could be enhanced

# %% [markdown]
#  * Some aspects are either incomplete or could, at least, be refined

# %% [markdown]
# ## Answers to Research Questions

# %% [markdown]
# ***Which data transformations are best supported by analytical methods and for which transformations is visual support beneficial?***

# %% [markdown]
#  * In our case:
#   * Cleanup of missing and erroneous values, allowing fill and deletion
#   * Normalization of values regarding points in time and intervals
#   * Merging of time-oriented data columns, using average calculations
#
#
#  * More generally:
#   * When statistics are involved
#   * Whenever batched or whole dataset
#   * Fully automated when rather straightforward

# %% [markdown]
# ***How do concrete data wrangling workflow processes look like and how can these processes be supported by VA methods?***

# %% [markdown]
#  * Such processes are oftentimes of exploratory nature
#  * Thus, we are supporting them visual-interactively
#  * Plus, especially repetitive actions are well suited

# %% [markdown]
# Instead of fiddling around with the data manually,<br>
# applying hand-crafted scripts, mainly tapping in the dark:
#
# → Clear **overview** plus transformation **suggestions** are conveniently **presented** and at the **fingertips**.

# %% [markdown]
# ***What data wrangling tasks need to be tackled in particular when dealing with time-oriented data and how can we support them with VA methods?***

# %% [markdown]
#  * Directly editing single values
#  * Deleting rows, also in batches
#  * Unifying temporal formats
#  * Cleaning up missing and erroneous values
#  * Spotting anomalies respectively outliers
#  * Transforming values of certain fields batch-wise
#  * Possibly “normalizing” these to some other specified value
#  * Merging columns according to some algorithm

# %% [markdown]
# ***How can we support data wrangling with VA techniques?***

# %% [markdown]
#  * By focusing on tasks which are:
#   * Related to **batched** data transformation operations
#   * As well as of rather **complex** nature
#
# → Requiring special attention and oversight.

# %% [markdown]
# These are tasks where fully automated approaches fall short, comparatively.
#
# → Human empowered through VA techniques can, still, perform better.

# %% [markdown]
# # Future Work

# %% [markdown]
#  * Refining and adding transformations

# %% [markdown]
#  * Addressing scalability issues of visualizations

# %% [markdown]
#  * Enabling undo and easy repetition of operations

# %% [markdown]
#  * Emphasizing more and, thus, enhancing the inference aspect

# %% [markdown]
#  * Taking care of data types other than time-oriented as well

# %% [markdown]
# # Conclusion

# %% [markdown]
# The **sweet spot** is most probably located somewhere in between:
#
# Augmenting an **interactive interface**<br>
# driven by **powerful visualizations**<br>
# with **semi-automatic suggestions**,<br>
# reasonably.

# %% [markdown]
#  * **[Thomas and Cook, 2005]** James J Thomas and Kristin A Cook. *Illuminating the Path: The Research
# and Development Agenda for Visual Analytics*. IEEE Computer Society, 2005.
#  * **[Loukides, 2010]** Mike Loukides. What is Data Science?
# O’Reilly Media, June 2010.
# <https://www.oreilly.com/ideas/what-is-data-science>, Accessed: 2017-04-11.
#  * **[Kandel et al., 2011]** Sean Kandel, Andreas Paepcke, Joseph Hellerstein, and Jeffrey Heer. Wrangler: Interactive Visual Specification of Data Transformation Scripts. In *Proceedings of the SIGCHI Conference on Human Factors in Computing Systems*, CHI ’11, pages 3363–3372, New York, NY, USA, 2011. ACM.
#  * **[Khan, 2015]** Rashid Khan. Timelion: The Time Series Composer for Kibana. Elastic,
# November 2015. <https://www.elastic.co/blog/timelion-timeline>, Accessed:
# 2017-04-11.
#  * **[Munzner, 2009]** Tamara Munzner. A Nested Model for Visualization Design and Validation.
# *IEEE Transactions on Visualization and Computer Graphics*, 15(6):921–928,
# November 2009.
#  * **[Miksch and Aigner, 2014]** Silvia Miksch and Wolfgang Aigner. Special Section on Visual Analytics: A
# Matter of Time: Applying a Data–Users–Tasks Design Triangle to Visual
# Analytics of Time-Oriented Data. *Computer & Graphics*, 38:286–290, February
# 2014.
#  * **[Cooper, 2004]** Alan Cooper. *The Inmates Are Running the Asylum*. Sams - Pearson Education, 2nd edition, 2004.
#  * **[Holzinger, 2005]** Andreas Holzinger. Usability Engineering Methods for Software Developers.
# *Communications of the ACM*, 48(1):71–74, January 2005.
#  * **[Nielsen, 1993]** Jakob Nielsen. *Usability Engineering*. Morgan Kaufmann, 1993.
#  * **[Forsell and Johansson, 2010]** Camilla Forsell and Jimmy Johansson. An Heuristic Set for Evaluation in Information Visualization. *AVI ’10 Proceedings of the International Conference
# on Advanced Visual Interfaces*, 10(3):199–206, 2010.
